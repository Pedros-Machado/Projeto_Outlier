# %% [markdown]
# <a name="topo"></a>

# %% [markdown]
# # Sumário
#
# 1. [Indicadores de Performance](#inicio)
# <br>
#
# 2. [Dividendos](#dividendos)
# <br>
#
# 3. [Simulando um Portifólio](#portifo)
# <br>
#
# 4. [Indicadores Contábeis](#contab)

# %% [markdown]
#  <a name="inicio"></a>

# %% [markdown]
# # Indicadores de Performance
#
# <br>
#
# - Podemos observar o desempenho dos ativos através de seus Preços de Fechamento Ajustados
#
# [início](#topo)
#
# <br>
#
# Dados de 2017-01-02 até 2023-04-06:
#
# __CAGRs Preço de Fechamento Ajustado em % a.a:__
# - ALPA4 == 0.33
# - SAPR4 == 7.37
# - BOVA11 == 8.89
# - KLBN4 == 8.89
# - ENGI11 == 18.3
# - EQTL3 == 18.45
# - TAEE11 == 19.72
# - VALE3 == 28.38
# - RENT3 == 31.19
# - WEGE3 == 37.96
# - MGLU3 == 42.35
# - UNIP6 == 77.56
# - PRIO3 == 100.87

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%282%29.png](attachment:Figure%202023-04-13%20152454%20%282%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%285%29.png](attachment:Figure%202023-04-13%20152454%20%285%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%286%29.png](attachment:Figure%202023-04-13%20152454%20%286%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%287%29.png](attachment:Figure%202023-04-13%20152454%20%287%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%288%29.png](attachment:Figure%202023-04-13%20152454%20%288%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%289%29.png](attachment:Figure%202023-04-13%20152454%20%289%29.png)

# %% [markdown]
# __Vemos que PRIO3 E UNIP6 performaram muito bem:__
#
# - Sharpe > 1
# - Ótimos CAGRs
# - Correlação relativamente baixa com o BOVA11 == [0.52 , 0.45]
#
# [início](#topo)

# %% [markdown]
#  <a name="dividendos"></a>

# %% [markdown]
# # Dividendos
#
# - Podemos observar o pagamento de dividendo dos ativos através de dados do Yahoo Finance
#
# [início](#topo)
#
# <br>
#
# __Dados de 2017-01-02 até 2023-04-06:__
#
# - BOVA11.SA: Não foi encontrado pagamento de dividendo
#
# - PRIO3.SA: Não foi encontrado pagamento de dividendo
#
# <br>
#
# Foram realizados:
#
# [0, 0, 36, 27, 12, 10, 23, 8, 13, 16, 27, 13, 18] pagamentos de dividendo.
#
# <br>
#
# __Yield Médio de:__
# - BOVA11 == 0%
# - PRIO3 == 0%
# - WEGE3 == 0.26%
# - RENT3 == 0.3%
# - MGLU3 == 0.39%
# - ALPA4 == 0.63%
# - KLBN4 == 1.31%
# - EQTL3 == 1.6%
# - ENGI11 == 1.84%
# - SAPR4 == 2.7%
# - TAEE11 == 3.2%
# - VALE3 == 4.05%
# - UNIP6 == 7.65%
#
# [início](#topo)

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%283%29.png](attachment:Figure%202023-04-13%20152454%20%283%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# __Tempo Médio entre os Pagamentos de Dividendo:__
# - BOVA11 == 0d
# - PRIO3 == 0d
# - WEGE3 == 59d
# - TAEE11 == 79d
# - RENT3 == 80d
# - KLBN4 == 96d
# - UNIP6 == 119d
# - SAPR4 == 138d
# - MGLU3 == 139d
# - ENGI11 == 170d
# - VALE3 == 179d
# - ALPA4 == 188d
# - EQTL3 == 261d
#
# [início](#topo)

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%284%29.png](attachment:Figure%202023-04-13%20152454%20%284%29.png)

# %% [markdown]
# <a name="portifo"></a>

# %% [markdown]
# # Simulando um Portifólio
#
# <br>
#
# - Vamos então imaginar como teria performado um portifólio de R$ 10.000,00 contendo estes ativos

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%2810%29.png](attachment:Figure%202023-04-13%20152454%20%2810%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%2811%29.png](attachment:Figure%202023-04-13%20152454%20%2811%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20152454%20%2812%29.png](attachment:Figure%202023-04-13%20152454%20%2812%29.png)

# %% [markdown]
# __Note que:__
#
# - 3 ativos superaram o desempenho do portifólio
# - MGLU3, PRIO3 e UNIP6
# - MGLU3 entregou em 2021-2023, boa parte da performance obtida nos anos anteriores
#
# <br>
#
# __Tipo do Portifólio é: Igualmente distribuído.__
#
# - Seu retorno acumulado foi de __1058.64%__
#
# - Seu retorno anualizado foi de __48.59%__
#
# - Sua volatilidade anualizada foi de __32.82%__
#
# - Seu sharpe anualizado foi de __0.956__
#
# [início](#topo)

# %% [markdown]
# <a name="contab"></a>

# %% [markdown]
# # Indicadores Contábeis
#
# <br>
#
# - Podemos observar o desempenho contábil através dos demonstrativos coletados da página statusinvest
# - Verificaremos primeiro o crescimento anualizado de alguns indicadores
#
# [início](#topo)

# %% [markdown]
# __CAGRs Receita em  % a.a:__
# - TAEE11 == 7.27
# - SAPR4 == 8.53
# - WEGE3 == 14.05
# - MGLU3 == 14.87
# - RENT3 == 15.46
# - EQTL3 == 24.63
# - UNIP6 == 28.6
# - PRIO3 == 76.96

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%280%29.png](attachment:Figure%202023-04-13%20163610%20%280%29.png)

# %% [markdown]
# <br>

# %% [markdown]
# __CAGRs Custos em  % a.a:__
# - SAPR4 == 9.31
# - RENT3 == 13.91
# - WEGE3 == 14.24
# - TAEE11 == 14.77
# - MGLU3 == 14.93
# - EQTL3 == 25.16
# - UNIP6 == 27.94
# - PRIO3 == 72.1
#
# [início](#topo)

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%281%29.png](attachment:Figure%202023-04-13%20163610%20%281%29.png)

# %% [markdown]
# <br>

# %% [markdown]
# __CAGRs Dívida Bruta em  % a.a:__
# - WEGE3 == 2.12
# - TAEE11 == 4.57
# - UNIP6 == 14.48
# - SAPR4 == 14.9
# - MGLU3 == 15.7
# - RENT3 == 26.12
# - EQTL3 == 28.98
# - PRIO3 == 94.08
#
# [início](#topo)

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%282%29.png](attachment:Figure%202023-04-13%20163610%20%282%29.png)
#
# [início](#topo)

# %% [markdown]
# __Note que:__
#
# - O crescimento da receita, dos custos e da dívida bruta de PRIO3 são outliers.

# %% [markdown]
# __CAGRs Ativo Total em  % a.a:__
# - TAEE11 == 5.47
# - SAPR4 == 9.45
# - WEGE3 == 11.06
# - PRIO3 == 15.26
# - UNIP6 == 20.52
# - MGLU3 == 22.35
# - RENT3 == 28.83
# - EQTL3 == 30.15

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%287%29.png](attachment:Figure%202023-04-13%20163610%20%287%29.png)
#
# [início](#topo)

# %% [markdown]
# - Agora, iremos observar o Histórico de alguns Indicadores através de Gráficos de Linha

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%283%29.png](attachment:Figure%202023-04-13%20163610%20%283%29.png)
#
# [início](#topo)

# %% [markdown]
# __Note que:__
#
# - EQTL3, PRIO3 e WEGE3 foram as __únicas empresas com crescimento de lucro líquido__ no período 2020-2021.
# - MGLU3 está dando __prejuízo__.

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%284%29.png](attachment:Figure%202023-04-13%20163610%20%284%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%285%29.png](attachment:Figure%202023-04-13%20163610%20%285%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%2810%29.png](attachment:Figure%202023-04-13%20163610%20%2810%29.png)
#
# [início](#topo)

# %% [markdown]
# __Note que:__
#
# - EQTL3, MGLU3 e RENT3 tem uma __grande concentração de capital de terceiros__ como fonte de financiamento.
# - Isto pode ser um problema, o __ideal seria financiar as aquisições de ativos com recursos injetados pelos proprietários__.

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%2815%29.png](attachment:Figure%202023-04-13%20163610%20%2815%29.png)
#
# [início](#topo)

# %% [markdown]
# __Note que:__
#
# - WEGE3 e MGLU3 tem uma __grande concentração de seu endividamento no curto prazo__.
# - Isto pode ser um problema, o __ideal seria ter como foco do endividamento, o longo prazo__.

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%2812%29.png](attachment:Figure%202023-04-13%20163610%20%2812%29.png)
#
# [início](#topo)

# %% [markdown]
# __Note que:__
#
# - PRIO3 teve seu __Ativo Circulante < Passivo Circulante no período 2018-2019__.
# - SAPR4 teve seu __Ativo Circulante < Passivo Circulante no período 2017-2018__.

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%2814%29.png](attachment:Figure%202023-04-13%20163610%20%2814%29.png)
#
# [início](#topo)

# %% [markdown]
# <br>

# %% [markdown]
# ![Figure%202023-04-13%20163610%20%2813%29.png](attachment:Figure%202023-04-13%20163610%20%2813%29.png)
#
# [início](#topo)
